# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("bmh")

# %%
df = pd.read_csv("./advertising.csv")
df.drop('Unnamed: 0',inplace = True, axis = 1)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
fig, ax = plt.subplots(1,3)
fig.set_size_inches(10,6)
sns.regplot(data= df, x= 'TV', y= 'sales',ax= ax[0])
sns.regplot(data= df, x= 'radio', y= 'sales',ax= ax[1])
sns.regplot(data= df, x= 'newspaper', y= 'sales',ax= ax[2])
plt.show()

# %% [markdown]
# 2.4 Exercises
# Conceptual
# 1. For each of parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.
# <ol>
#     <li>
# (a) The sample size n is extremely large, and the number of predictors p is small. <font color = 'red'> Flexible method is better as we can learn complex data patterns better </font> </li>
#     <li>
# (b) The number of predictors p is extremely large, and the number of observations n is small.<font color = 'red'> Inflexible method as we would be overfitting the same dataset </font> </li>
#     <li>
# (c) The relationship between the predictors and response is highly non-linear <font color = 'red'> Flexible as the dataset has complex patterns </font> </li>
#     <li>
# (d) The variance of the error terms, i.e. σ2 = Var(), is extremely high.<font color = 'red'> Flexible method as the data can capture complex patterns </font> </li>
# </ol>
# 2. Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediction. Finally, provide n and p.
# <ol>
#     <li>
# (a) We collect a set of data on the top 500 firms in the US. For each firm we record profit, number of employees, industry and the CEO salary. We are interested in understanding which factors affect CEO salary. <font color = 'red'> Regression / Inference, n= 500, p = 4 </font></li>
#     <li>
# (b) We are considering launching a new product and wish to know whether it will be a success or a failure. We collect data on 20 similar products that were previously launched. For each product we have recorded whether it was a success or failure, price charged for the product, marketing budget, competition price, and ten other variables.<font color = 'red'> Classification/Prediction/n=20, p = 14 </font></li>
#     <li>
# (c) We are interested in predicting the % change in the USD/Euro exchange rate in relation to the weekly changes in the world stock markets. Hence we collect weekly data for all of 2012. For each week we record the % change in the USD/Euro, the % change in the US market, the % change in the British market, and the % change in the German market.<font color = 'red'> Regression/Prediction/n =52, p = 4 </font></li>
# </ol>
# 3. We now revisit the bias-variance decomposition.
# <ol>
#     <li>
# (a) Provide a sketch of typical (squared) bias, variance, training error, test error, and Bayes (or irreducible) error curves, on a single plot, as we go from less flexible statistical learning methods towards more flexible approaches. The x-axis should represent the amount of flexibility in the method, and the y-axis should represent the values for each curve. There should be five curves. Make sure to label each one. <img src="./IMG_3333.jpg" width = "500" height = "500"> </li>
#     <li>
# (b) Explain why each of the five curves has the shape displayed in part (a) <font color = 'red'>
#         <ol> <li> Bias of a model is a function of its complexity , measures the error due to difference in actual function to approximate function used </li>
#             <li> Variance of a model is function of how much the predictions change if the underlying dataset changes, if higher the flexibility, higher the model is fit to dataset, so changes in the underlying dataset can cause huge changes in predictions </li>
#             <li> Training Error always decreases as we move to more flexible models as the models we use ultimately tries to fit the dataset more accurately </li>
#             <li> Test Error keeps decreasing because we are reducing the error initally by going to better models, but gradually increases as we increase the model complexity because the model we learnt does not generalize enough to make its predictions on test dataset</li>
#             <li> Bayes or Irreducible error always remains constant and is greater than 0 because we cannot account for all the factors that we need to simulate a particular scenario </li>
#         </ol>
#         </font> </li>
#         </ol>
#
# 5. What are the advantages and disadvantages of a very flexible (versus a less flexible) approach for regression or classification? Under what circumstances might a more flexible approach be preferred to a less flexible approach? When might a less flexible approach be preferred? <font color = 'red'> Flexible model is used when our foucs is to attain the best accuracy possible where as restricted models are used when we are not focussing on prediction but are looking for underlying factors that are producing the outcome and infer from the data </font>
# 6. Describe the differences between a parametric and a non-parametric statistical learning approach. What are the advantages of a parametric approach to regression or classification (as opposed to a nonparametric approach)? What are its disadvantages?
# <font color = 'red'> Parametric approach tries to assume the output function to be of some form and then uses the data to find the parameters of the functioin where as non parametric approach does not preassume any functional form of outcome variable and tries to use some kind of metric to minimize the error. Advantages of Parametric model: This is mostly used to inference as we know how the output function looks like and come up with inferences. Non Parameteric models are used for accurate preductions </font>
# 7. The table below provides a training data set containing six observations, three predictors, and one qualitative response variable.
# X1 X2 X3 Y
# 1 0 3 0 Red
# 2 2 0 0 Red
# 3 0 1 3 Red
# 4 0 1 2 Green
# 5 −1 0 1 Green
# 6 1 1 1 Red
# Suppose we wish to use this data set to make a prediction for Y when X1 = X2 = X3 = 0 using K-nearest neighbors.
# (a) Compute the Euclidean distance between each observation and the test point, X1 = X2 = X3 = 0.
# (b) What is our prediction with K = 1? Why?
# (c) What is our prediction with K = 3? Why?
# (d) If the Bayes decision boundary in this problem is highly nonlinear, then would we expect the best value for K to be large or
# small? Why?

# %%
#Problem 6 Solution
import math
mat = [[1,0,3],[2,0,0],[0,1,3],[0,1,2],[-1,0,1],[1,1,1]]
out = ['red','red','red','green','green','red']
test = [0,0,0]
def euclid_3_d(x, y):
    return math.sqrt( math.pow((x[0] - y[0]),2) + math.pow( (x[1] - y[1]) ,2) + math.pow( (x[2] - y[2]) ,2)  )
distances = []
for x in mat:
    distances.append(euclid_3_d(test,x))
print(distances)
#a) prediction with K = 1 will be green as it has the shortest distance and we chose K =1 which gives nearest neighbor
#b) prediction with K =3 will be mode (green,red,red) = red as we chose K  = 3 and we pick the max class which reduces the error
#c) If our decision boundary is non linear, smaller K would be better as it would pick the mode class near the point whereas
#   if we pick higher K, it would chose the class that is global to dataset and may not be good enough to learn the non linear
#   boundaries
# Out:
# [3.1622776601683795, 2.0, 3.1622776601683795, 2.23606797749979, 1.4142135623730951, 1.7320508075688772]
